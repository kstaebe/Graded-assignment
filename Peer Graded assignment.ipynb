# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __KStaebe__
#
# Data Scientist

# %% [markdown]
# _I am interested in transitioning to a career as a data scientist as I found wrestling with large datasets was something I enjoyed very much in my old career._

# %% [markdown]
# ### A simple addition

# %%
a = 234
b = 95
c = a + b
print(c)
# Out:
# 329

# %% [markdown]
# A selection of Markdown formatting examples
# ***
#
# Here is a list:
# 1. Of
# 2. Things
# 3. That
#     * You
#     * Can
#     * Do
#     * In
# 4. Markdown
#
# |   | Yes | No |
# |---|-----|----|
# | 1 |  Y  | N  |
# | 2 |  Y  | N  |
#
# [Here is the weather in Oslo](https://www.yr.no/en/forecast/daily-table/1-2760700/Norway/Oslo/Oslo)
#
# ![nyan-cat.gif](attachment:nyan-cat.gif)
